# %% [markdown]
# **This code present prompts stratgies for Feminism Movements.**

# %%
pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.5/75.5 kB 1.7 MB/s eta 0:00:00
# ...

# %%
import openai
import csv
import random

# %%
openai.api_key= 'OPENAI_API_KEY'

# %% [markdown]
# #Firts approach: General and simple prompts for all stance

# %% [markdown]
# Here we asked the model to create and add the label in same time..
# You can notice some mistakes in labelling.

# %%
#Asking ChatGPT create the tweets
prompt = '''
    Task:Create 10 informal tweets related to feminisim with different stance (favour, against , or none) for each tweet.
         The tweets may include errors slang, emojis, mentions and hashtags.
         Generate equall numbers of tweets for each stance.
    The output: Short Tweet (Maximum of 15 words). (Tweet) : [stance]
    '''
response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a tweet generator"},
            {"role": "user", "content": prompt}
        ],
        max_tokens=1000,
        n=10,
        temperature=1,
    )

#print ChatGPT answers
for respon in response['choices']:
    tweet = respon['message']['content'].strip()
    print(tweet)
# Out:
# 1. "Who run the world? Girls! 💃✨ #Feminism" : [Favor]
# 2. "Not afraid to speak my mind, because feminism is about equality. 💪 #LevelThePlayingField" : [Favor]
# 3. "Just because I'm a woman, doesn't mean I need a man to validate me. 🙅‍♀️ #Independent" : [Favor]
# 4. "Feminism isn't about hating men, it's about empowering women. 🌸✊ #EqualityForAll" : [Favor]
# 5. "Can't believe some people think we don't need feminism anymore. 🤦‍♀️ #WakeUp" : [Against]
# 6. "Equality doesn't mean taking away men's rights, it means leveling the field. 🙌✨ #GenderEquality" : [Against]
# 7. "Don't need a label to fight for equal rights, actions speak louder. 💁‍♀️ #Empowerment" : [Against]
# 8. "Feminism is a movement, not a man-hating club. Get your facts straight. 🙄 #EducateYourself" : [Against]
# 9. "To all the haters who say feminism is unnecessary, walk a mile in our heels. 👠 #WalkAMile" : [None]
# ...

# %% [markdown]
# #Second approach: Specific prompt for each stance

# %% [markdown]
# Here we create tweets for each stance separately..

# %%
def create_tweets(prompt_, total_tweet):

    prompt = prompt_
    Generated_tweets = []
    #ask ChatGPT create tweets
    response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
            {"role": "system", "content": "You are a tweet generator"},
            {"role": "user", "content": prompt}
        ],
    max_tokens=100,
    n=total_tweet,
    temperature=1
    )

    #add the responses to the list
    for respon in response['choices']:
      tweet = respon['message']['content'].strip()
      Generated_tweets.append(tweet)

    return Generated_tweets

#save the tweets in csv file
def save_tweets_csv(tweets, label):
    with open('feminism_inst_few_non_new.csv', 'w', newline='', encoding='utf-8-sig') as csvfile:
        colum_names = ['Tweet', 'Label']
        writer = csv.DictWriter(csvfile, fieldnames= colum_names)
        writer.writeheader()

        for tweet in tweets:
            writer.writerow({'Tweet': tweet, 'Label': label})

# %%
#prompts for each stance
#for each set of tweets we slightly chang the Task and use different tweets examples ...

#1: for favour satnce
prompt1 = '''
    Task: create an informal tweet that support feminism. The tweet may include errors slang, mention and hashtag.
    Type of Text: short Tweet (Maximum of 20 words).
    The output: should include the tweet only.

    Example: Abusive Misogynist  @user whining that feminists are blocking him. Let's make his day and all bock him. #YesAllWomen #SemST
    Example: Women are superior to men in every aspect #feminist #SemST
    Example: my coworker called me gay because i didn't stare at these girls who came in, SORRY but i respect women and this is why i need #SemST
    '''

#2: for Against
prompt2 = '''
    Task: generate an informal tweet that goes against feminism. The tweet may include errors slang, mention and hashtag.
    Type of Text: Short Tweet (Maximum of 20 words).
    The output: should include the tweet only.

    Example: Why should woman stick together?  I don't like half of you cunts. #antifeminist
    Example: Feminists are so stupid they think they're the only ones who can have freedom of speech Lmaooo #SemST
    Example: Can't find it in me to be friends with people who throw around the word 'slut' or judge women for being sexual beings.#SemST
    '''
#3: for NONE stance
prompt3 = '''
    Task: Create an informal tweet that not have clear stance towards feminism or may not related but use related hashtag. The tweet may include errors slang, mention and hashtag.
    Type of Text: Short Tweet (Maximum of 20 words).
    The output: should include the tweet only.

    Example: Gender research helps to develop nursing research  theoretical frameworks, concepts and methodology. #research #feminism
    Example: @user does a vegan diet make you immortal? either way we're all gonna die #SemST #feminism
    Example: were even is the clifford on a Virginia? #stophidingit #SemST
    '''

# %%
# create tweets by choose the stance prompt 1, 2, or 3 and specify number of tweets
total_tweet= 100 #(no more than 128 as it limited number for n parameter)
label='FAVOR'
synthetic_tweets = create_tweets(prompt1, total_tweet)

# save tweets in CSV
save_tweets_csv(synthetic_tweets, label)

# %% [markdown]
# # Third approach: Template prompt for each stance

# %% [markdown]
# Here we create specific subtopics may not coverd in second approach

# %%
#function to ask ChatGPT
def create_tweets(sys_prompt, prompt):

    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": sys_prompt},
            {"role": "user", "content": prompt},
        ],
        max_tokens=100,
        n=1,
        temperature=1,
    )
    return response.choices[0].message.content.strip()

#Function to set the hint sentence and then call create_tweets to create the tweets
def set_propmts(num_tweets, templ, hasht, topic, base_P):
    tweets = []
    templates = templ
    hashtags = hasht
    topics = topic

    for _ in range(num_tweets):
        template = random.choice(templates)
        hashtag = random.choice(hashtags)
        topic = random.choice(topics)
        prompt = f"{template} {topic}. {hashtag}"
        base_prompt= base_P
        full_prompt= "Hint: "+ prompt
        tweet = create_tweets(base_prompt, full_prompt)
        tweets.append(tweet)

    return tweets

# %%
#1: prompts for Favor stance consist of base_prompt1 for the system, and the hint sentence lists' to create hint sentence.
#Important: make sure the lists coherent each for each subset of tweets by add comments to some elements to avoid unwanted results.
base_prompt1= '''
    You are a tweet generator.
    Task: Create an informal tweet that support feminism. Inspire your perspective from the hint, and use the exact hashtag correctly.
          The hint is consist of "template, Topic. hashtag", use your creativity to generate the tweet without copy the template.
    The output: Short Tweet (Maximum of 20 words) and include the tweet only.

    Example: "Hint: you know what's awesome? Feminism!, [reproductive rights for all]. #GenderEquality"
    Answer:  "feminism rocks! Let's make sure everyone has access to reproductive healthcare and their rights. #GenderEquality"

    Example: "Hint: "No more respectability politics. We're demanding change [all body types].#AgainstFeminism"
    Answer: ""no more body-shaming nonsense!, #AgainstFeminism?? Feminism is about inclusivity and embracing all body types"

    Example:"@user you mean womem...??, [women in leadership roles]# familism"
    Answer: "women rocking careers and nurturing families, breaking stereotypes and embracing, @user the end!"
    '''

templates1 = [
    "you know what's awesome? Feminism!, ",
    #"hey @user, you gotta fight for feminism and ...",
    "time to level the playing field like never before...",
    #"Let's slay the patriarchy and...",
    #"no more respectability politics. We're demanding...",
    #"guys, embracing feminism can ... ",
    "gender justice has been overdue for ages!, ",
    #"breaking down barriers with feminism, like a boss...",
    "It's time to amplify women's voices and stories!, ",
    "@user why you think women...?, they..",
    "no more excuses!...",
    "support us @user and ...",
    "We're demanding..."
    ]

hashtags1= [
        "#GenderEquality",
        "#WomenEmpowerment",
        "#Feminism",
        "#YesAllWomen",
        "#AgainstFeminism"
    ]

topics1 = [
        "[contributions of women in society]",
        "[Equality and change societal norms]",
       #"[Awareness about gender-related issues]",
        "[combating Sexism and Misogyny]",
        "[dismantle stereotypes]",
        "[women in leadership roles]"
        "[reproductive rights for all]"
        "[adress negative name-calling for women]"
       #"[Gender Equality in Various Contexts]",
        "[addresses reactions to feminism]",
        "[the role of men for women]"
        "[challenging gender stereotypes]",
       #"[putting an end to gender-based violence]",
       #"[all body types]",
        "[intersectionality in feminism]",
        "[workplace discrimination]"
    ]

#2: prompts for Against stance
base_prompt2= '''
    You are a tweet generator.
    Task: Create an informal tweet that tweet that goes against feminism. Inspire your perspective from the hint, and use the exact hashtag correctly.
          The hint is consist of "template, Topic. hashtag", use your creativity to generate the tweet without copy the template.
    The output: Short Tweet (Maximum of 20 words) and include the tweet only.

    Example: "Hint: "you know what's problematic? Feminism! [feminism movements causing harm to society]. "#AgainstFeminism"
    Answer: "Problem alert! Feminism can create more issues than it solves. We need a better approach. #AgainstFeminism"

    Example: "Feminists don't even understand, [family dynamics and traditional roles].#Feminism"
    Answer: "Don't let feminists dictate how our families should function. Traditional roles bring harmony. #Feminism"

    Example: "feminism undermines traditional values and societal norms, [recognizing men's rights]. #AgainstFeminism "
    Answer: "feminism, why mess with traditional values? Let's embrace what's worked for centuries! ##AgainstFeminism"

    '''

templates2 = [
        "You know what's problematic? Feminism!",
        #"feminism is flawed because...",
        "WE don't need feminism to ..",
        #"Let's question the idea of slaying the patriarchy and...",
        "No more anti-men politics. WE HAVE TO...",
        #"we must prioritize other issues, feminism not everything...",
        #"gender justice is irrelevant...",
        #"feminism perpetuates victimhood instead of empowerment.",
        #"Feminism overlooks the importance of..",
        #"@user we're resisting any change...",
        "Stupid Feminists, the.."
        #"Not all gender disparities are a result of discrimination.",
        #"Equality doesn't mean privileging one gender over another.",
        #"feminism undermines traditional values and societal norms,"
        "Feminists don't even understand , ",
        #"guys, resisting feminism can...",
        "I can't believe people needs for feminism??? So Silly ",
        "I'm Not going to walk you thru this @user because.."
    ]

hashtags2 = [
     "#AgainstFeminism",
     "#CritiqueFeminism",
     #"#RejectToxicFeminism",
     "#MensRights",
     "#NoFeminism",
     "#Feminism"
    ]
topics2 = [
        "[Critique of Feminist Issues]",
       #"[questions the legitimacy of feminist movements]",
       #"[challenges the need for gender equality]",
       #"[feminism movements causing harm to society]",
        "[Gamergate controversy]",
        "[concerns about the achievement of true equality]",
        "[family dynamics and traditional roles]",
       #"[biological differences between genders]",
        "[men's issues and challenges]",
       #"[critique of gender quotas or affirmative action]",
       #"[cultural preservation and resistance to Western feminism]",
       #"[valuing traditional gender roles]",#
       "[recognizing men's rights]",#
       #"[addressing violence against men]",
       "[feminism create animosity between genders]",
        "[women ignore real duties]",
       #"[feminism labeling masculinity as toxic]"

    ]

#3: prompts for None stance
base_prompt3= '''
    You are a tweet generator.
    Task: Create an informal tweet that not support or criticize feminism, and may not related to feminism. Inspire your perspective from the hint. use hashtags and mentions.
          The hint is consist of "template, Topic. hashtag", use your creativity to generate the tweet without copy the template.
    The output: Short Tweet (Maximum of 20 words) and include the tweet only.

    Example: "Hint: Gender equality is amazing! [Climate change action]. ##GenderEquality"
    Answer: "Addressing climate change requires a commitment to #GenderEquality. Let's work together for a greener and more inclusive future!"

    Example: "Hint: "Together, we can create a better world... [Mental health awareness].#Feminism"
    Answer:  "Remember, self-care is crucial for our well-being. Take time to prioritize your mental health. #Feminism"

    Example: "People say I'm a bit.. [Black Lives Matter] #AgainstFeminism"
    Answer: ""Supporting one cause doesn't mean dismissing others. Let's strive for a world that values all lives. #AgainstFeminism"
    '''

templates3 = [
    "People say I'm a bit.. ",
    "Together, we can create a better world...",
   #"Gender equality is amazing!",
   #"Communists can relate to..",
    "Can't win for trying on @user ..",
   #"The meaning of peace is the absence of...",
    "The statistics show that...",
    "All wat I need now is a ..."
]

hashtags3 = [
      "#Feminism",
      "#YesAllWomen",
      "#AgainstFeminism",
      "#GamerGate"
]

topics3 = [

    # "[climate change action]",
      "[mental health awareness]",
    #"[Black Lives Matter]",
    #"cybersecurity challenges",
    #"[financial literacy]",
     "[space exploration]",
     "[a wonderful TV show]",
    #"[everyone voice is matter]",
     "[freinds day!]",
     "[love is all thing]"
]

# %%
#call the function for each stance separately
num_tweets = 50   #set number of tweets to create subset of tweets by choos the elements of the lists
feminist_favour = set_propmts(num_tweets, templates1, hashtags1, topics1, base_prompt1 )
#feminist_against = set_propmts(num_tweets, templates2, hashtags2, topics2, base_prompt2 )
#feminist_none = set_propmts(num_tweets, templates3, hashtags3, topics3, base_prompt3 )

#save the tweets in CSV file
with open("feminist_template_fav.csv", 'w', newline='', encoding='utf-8-sig') as file:
    writer = csv.writer(file)
    writer.writerow(["Tweet", "Label"])
    for data in feminist_favour:
        writer.writerow([data, "FAVOR"])
